# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio de Regex:

# %% [markdown]
# ### Ejercicio 1: Extracción de datos.
#
# Recuerda que necesitamos hacer importaciones antes de enfrentarnos a un problema.

# %%
# Importaciones:
## Para trabajar con expresiones regulares
import re 

## Para contar las palabras de un texto 
from collections import Counter

# %% [markdown]
# Dado el archivo `datos_artistas.txt` usa las **expresiones regulares** para extraer los siguientes datos, con el código que encontrarás en la siguiente celda:

# %%
with open('Datos/datos_artistas.txt', 'r', encoding='utf-8') as archivo:
    contenido = archivo.read()

print(contenido[:200])
# Out:
# BobDylan bob.dylan@gmail.com -1 123456789 http://bobdylan.com Like a Rolling Stone - 6:13 1965 Once upon a time you dressed so fine
# Threw the bums a dime in your prime, didn't you?
# People call say 'be

# %%
print(contenido)
# Out:
# BobDylan bob.dylan@gmail.com -1 123456789 http://bobdylan.com Like a Rolling Stone - 6:13 1965 Once upon a time you dressed so fine
# Threw the bums a dime in your prime, didn't you?
# People call say 'beware doll, you're bound to fall'
# You thought they were all kidding you
# You used to laugh about
# Everybody that was hanging out
# Now you don't talk so loud
# Now you don't seem so proud
# About having to be scrounging your next meal
# How does it feel, how does it feel?
# To be without a home
# Like a complete unknown, like a rolling stone
# Ahh you've gone to the finest schools, alright Miss Lonely
# But you know you only used to get juiced in it
# Nobody's ever taught you how to live out on the street
# And now you're gonna have to get used to it
# You say you never compromise
# With the mystery tramp, but now you realize
# He's not selling any alibis
# As you stare into the vacuum of his eyes
# And say do you want to make a deal?
# How does it feel, how does it feel?
# ...

# %% [markdown]
# #### 1.1 La información de cada artista(nombre, correo de contacto, número de contacto y sitio web).

# %%
Artistas=[]

patron_nombre = r"^\w+|\./\w+"
patron_correo=r"\S+@\S+"
patron_contacto=r"-\d+\s+\d+"
patron_sitioweb=r"http\S+"

nombre_artista=list(map(lambda x:x.strip("./"),re.findall(patron_nombre,contenido)))
print(nombre_artista)
correo_artista=re.findall(patron_correo,contenido)
print(correo_artista)
contacto_artista=re.findall(patron_contacto,contenido)
print(contacto_artista)
sitioweb_artista=re.findall(patron_sitioweb,contenido)
print(sitioweb_artista)

for i in range(len(nombre_artista)):
    dc= {"Nombre":nombre_artista[i],"Correo":correo_artista[i],"Numero":contacto_artista[i],"Sitio Web":sitioweb_artista[i]}
    Artistas.append(dc)

Artistas
# Out:
# ['BobDylan', 'TheBeatles', 'EltonJohn', 'Queen', 'MichaelJackson', 'Madonna', 'DavidBowie', 'Nirvana', 'Adele', 'EdSheeran', 'Beyoncé', 'TaylorSwift', 'Rihanna', 'Drake', 'KanyeWest', 'BrunoMars', 'ArianaGrande', 'Shakira', 'Coldplay', 'LadyGaga']
# ['bob.dylan@gmail.com', 'contact@thebeatles.co.uk', 'elton.john@hotmail.com', 'info@queenonline.com', 'michael.jackson@yahoo.com', 'madonna@madonna.com', 'david.bowie@outlook.com', 'contact@nirvana.com', 'adele@adele.com', 'ed.sheeran@gmail.com', 'beyonce@beyonce.com', 'taylor.swift@yahoo.com', 'rihanna@hotmail.com', 'drake@drake.com', 'kanye.west@gmail.com', 'bruno.mars@outlook.com', 'ariana.grande@yahoo.com', 'shakira@hotmail.com', 'info@coldplay.com', 'lady.gaga@gmail.com']
# ...

# %% [markdown]
# #### 1.2 La información de cada canción(título, duración y fecha de lanzamiento).

# %%
Canciones =[]

patron_titulo= r"http[^\s]+\s(.+)\s-"
patron_duracion= r"- (\d+\:\d+)"
patron_lanzamiento= r"\W(\d{4})\s"

titulo_cancion=re.findall(patron_titulo,contenido)
print(titulo_cancion)
print(len(titulo_cancion))
duracion_cancion=re.findall(patron_duracion,contenido)
print(duracion_cancion)
print(len(duracion_cancion))
lanzamiento_cancion=re.findall(patron_lanzamiento,contenido)
print(lanzamiento_cancion)
print(len(lanzamiento_cancion))

for i in range(len(titulo_cancion)):
    dc= {"Nombre":titulo_cancion[i],"Duración":duracion_cancion[i],"Año Lanzamiento":lanzamiento_cancion[i]}
    Canciones.append(dc)

Canciones
# Out:
# ['Like a Rolling Stone', 'Hey Jude', 'Your Song', 'Bohemian Rhapsody', 'Billie Jean', 'Like a Prayer', 'Space Oddity', 'Smells Like Teen Spirit', 'Someone Like You', 'Shape of You', 'Halo', 'Blank Space', 'Diamonds', 'Hotline Bling', 'Stronger', 'Uptown Funk', '7 Rings', "Hips Don't Lie", 'Yellow', 'Bad Romance']
# 20
# ['6:13', '7:11', '4:01', '5:55', '4:54', '5:43', '5:18', '5:01', '4:45', '3:53', '4:21', '3:52', '3:45', '4:27', '5:12', '4:30', '2:58', '3:38', '4:26', '4:54']
# 20
# ['1965', '1968', '1970', '1975', '1982', '1989', '1969', '1991', '2011', '2017', '2008', '2014', '2012', '2015', '2007', '2014', '2019', '2006', '2000', '2009']
# 20
# [{'Nombre': 'Like a Rolling Stone',
#   'Duración': '6:13',
#   'Año Lanzamiento': '1965'},
#  {'Nombre': 'Hey Jude', 'Duración': '7:11', 'Año Lanzamiento': '1968'},
#  {'Nombre': 'Your Song', 'Duración': '4:01', 'Año Lanzamiento': '1970'},
#  {'Nombre': 'Bohemian Rhapsody',
#   'Duración': '5:55',
#   'Año Lanzamiento': '1975'},
# ...

# %% [markdown]
# #### 1.3 Almacena la información en una lista de diccionarios donde cada diccionario contenga los datos de un artista y su canción asociada.

# %%
for i in range(len(nombre_artista)):
    dc= {"Nombre":nombre_artista[i],"Correo":correo_artista[i],"Numero":contacto_artista[i],"Sitio Web":sitioweb_artista[i]}
    Artistas.append(dc)

Artistas

for i in range(len(titulo_cancion)):
    dc= {"Nombre":titulo_cancion[i],"Duración":duracion_cancion[i],"Año Lanzamiento":lanzamiento_cancion[i]}
    Canciones.append(dc)

Canciones
# Out:
# [{'Nombre': 'Like a Rolling Stone',
#   'Duración': '6:13',
#   'Año Lanzamiento': '1965'},
#  {'Nombre': 'Hey Jude', 'Duración': '7:11', 'Año Lanzamiento': '1968'},
#  {'Nombre': 'Your Song', 'Duración': '4:01', 'Año Lanzamiento': '1970'},
#  {'Nombre': 'Bohemian Rhapsody',
#   'Duración': '5:55',
#   'Año Lanzamiento': '1975'},
#  {'Nombre': 'Billie Jean', 'Duración': '4:54', 'Año Lanzamiento': '1982'},
#  {'Nombre': 'Like a Prayer', 'Duración': '5:43', 'Año Lanzamiento': '1989'},
#  {'Nombre': 'Space Oddity', 'Duración': '5:18', 'Año Lanzamiento': '1969'},
#  {'Nombre': 'Smells Like Teen Spirit',
#   'Duración': '5:01',
#   'Año Lanzamiento': '1991'},
#  {'Nombre': 'Someone Like You', 'Duración': '4:45', 'Año Lanzamiento': '2011'},
#  {'Nombre': 'Shape of You', 'Duración': '3:53', 'Año Lanzamiento': '2017'},
#  {'Nombre': 'Halo', 'Duración': '4:21', 'Año Lanzamiento': '2008'},
#  {'Nombre': 'Blank Space', 'Duración': '3:52', 'Año Lanzamiento': '2014'},
# ...

# %% [markdown]
# ### Ejercicio 2: Análisis de datos
# Usa las **expresiones regulares** para extraer la siguiente información:

# %% [markdown]
# #### 2.1 Busca la palabra más repetida en el texto completo.

# %%
lista_de_palabra=contenido.split()

Counter(lista_de_palabra).most_common(1)
# Out:
# [('I', 342)]

# %% [markdown]
# #### 2.2 Busca la palabra que más repetida en cada cación.

# %%
texto_sin_saltos=" ".join(contenido.split("\n"))
print(texto_sin_saltos)

patron_letra= r"(?:\b\d{4}\b)(.*?)(\./)"

lista_de_letras=re.findall(patron_letra,texto_sin_saltos)
lista_de_letras2:[]
for tuplas in lista_de_letras:
    lista_de_letras2
# Out:
# BobDylan bob.dylan@gmail.com -1 123456789 http://bobdylan.com Like a Rolling Stone - 6:13 1965 Once upon a time you dressed so fine Threw the bums a dime in your prime, didn't you? People call say 'beware doll, you're bound to fall' You thought they were all kidding you You used to laugh about Everybody that was hanging out Now you don't talk so loud Now you don't seem so proud About having to be scrounging your next meal How does it feel, how does it feel? To be without a home Like a complete unknown, like a rolling stone Ahh you've gone to the finest schools, alright Miss Lonely But you know you only used to get juiced in it Nobody's ever taught you how to live out on the street And now you're gonna have to get used to it You say you never compromise With the mystery tramp, but now you realize He's not selling any alibis As you stare into the vacuum of his eyes And say do you want to make a deal? How does it feel, how does it feel? To be on your own, with no direction home A comple
# ...

# %% [markdown]
# #### 2.3 Busca el nombre de la canción que más dura.

# %%
duracion_max=0

for cancion in Canciones:
    duracion=int(cancion["Duración"][0])*60+int(cancion["Duración"][2:])
    if duracion>duracion_max:
        duracion_max=duracion
        cancion_max=cancion["Nombre"]

print(f"la cancion que mas dura es {cancion_max}, que dura {duracion_max} segundos")
# Out:
# la cancion que mas dura es Hey Jude, que dura 431 segundos

# %% [markdown]
# #### 2.4 Busca el nombre de la canción que menos dura.

# %%
duracion_min=duracion_max

for cancion in Canciones:
    duracion=int(cancion["Duración"][0])*60+int(cancion["Duración"][2:])
    if duracion<duracion_min:
        duracion_min=duracion
        cancion_min=cancion["Nombre"]

print(f"la cancion que menos dura es {cancion_min}, que dura {duracion_min} segundos")
# Out:
# la cancion que menos dura es 7 Rings, que dura 178 segundos

# %% [markdown]
# #### 2.5 Busca el nombre y la fecha de lanzamiento de la canción más actual.

# %%
año_max= 0
cancion_mas_actual = ""

for cancion in  Canciones:
    año_lanzamiento = int(cancion['Año Lanzamiento'])
    if año_lanzamiento > año_max:
        año_max = año_lanzamiento
        cancion_mas_actual = cancion

cancion_mas_actual
# Out:
# {'Nombre': '7 Rings', 'Duración': '2:58', 'Año Lanzamiento': '2019'}

# %% [markdown]
# #### 2.6 Calcula la cantidad de países a partir de los números de contacto.

# %%
prefijos_unicos = set()

for artista in Artistas:
    numero = artista['Numero']
    prefijo = numero.split()[0][1:]
    prefijos_unicos.add(prefijo)

cantidad_prefijos = len(prefijos_unicos)

print(f"la cantidad de paises de artistas es {cantidad_prefijos}")
# Out:
# la cantidad de paises de artistas es 9

# %% [markdown]
# #### 2.7 Agrupa las canciones por década.

# %%
decadas = {
    '1960s': [],
    '1970s': [],
    '1980s': [],
    '1990s': [],
    '2000s': [],
    '2010s': [],
}
for cancion in Canciones:
    año = int(cancion['Año Lanzamiento'])
    if 1960 <= año < 1970:
        decadas['1960s'].append(cancion)
    elif 1970 <= año < 1980:
        decadas['1970s'].append(cancion)
    elif 1980 <= año < 1990:
        decadas['1980s'].append(cancion)
    elif 1990 <= año < 2000:
        decadas['1990s'].append(cancion)
    elif 2000 <= año < 2010:
        decadas['2000s'].append(cancion)
    elif 2010 <= año < 2020:
        decadas['2010s'].append(cancion)

for decada, lista_canciones in decadas.items():
    print(f'Década de {decada}:')
    for cancion in lista_canciones:
        print(f"  - {cancion['Nombre']} ({cancion['Año Lanzamiento']})")
# Out:
# Década de 1960s:
#   - Like a Rolling Stone (1965)
#   - Hey Jude (1968)
#   - Space Oddity (1969)
#   - Like a Rolling Stone (1965)
#   - Hey Jude (1968)
#   - Space Oddity (1969)
# Década de 1970s:
#   - Your Song (1970)
#   - Bohemian Rhapsody (1975)
#   - Your Song (1970)
#   - Bohemian Rhapsody (1975)
# Década de 1980s:
#   - Billie Jean (1982)
#   - Like a Prayer (1989)
#   - Billie Jean (1982)
#   - Like a Prayer (1989)
# Década de 1990s:
#   - Smells Like Teen Spirit (1991)
#   - Smells Like Teen Spirit (1991)
# Década de 2000s:
#   - Halo (2008)
#   - Stronger (2007)
#   - Hips Don't Lie (2006)
#   - Yellow (2000)
#   - Bad Romance (2009)
#   - Halo (2008)
#   - Stronger (2007)
#   - Hips Don't Lie (2006)
#   - Yellow (2000)
#   - Bad Romance (2009)
# Década de 2010s:
#   - Someone Like You (2011)
#   - Shape of You (2017)
#   - Blank Space (2014)
#   - Diamonds (2012)
#   - Hotline Bling (2015)
#   - Uptown Funk (2014)
#   - 7 Rings (2019)
#   - Someone Like You (2011)
# ...
